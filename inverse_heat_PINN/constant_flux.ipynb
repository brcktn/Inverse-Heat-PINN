# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, Dataset
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

from google.colab import files, drive

# %%
# Hyperparameters
layers = [3, 64, 64, 64, 1]
lr = 0.001
batch_size = 32
epochs = 20

# Plate parameters
size = 2.0  # Length of the plate
t_max = 5.0  # Maximum time
alpha = 0.01  # Thermal diffusivity (known value)
q = 0.05  # Heat flux (known value)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# !wget -O constant_flux_DG.csv https://raw.githubusercontent.com/brcktn/Inverse-Heat-PINN/main/training_data/constant_flux_DG.csv

class CSVDataset(Dataset):
    def __init__(self, csv_file):
        self.data = pd.read_csv(csv_file).values.astype('float32')
        self.X = torch.tensor(self.data[:, 1:4])
        self.y = torch.tensor(self.data[:, 4:])

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = CSVDataset('constant_flux_DG.csv')

dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# next(iter(dataloader))  # Check the first batch
# Out:
# --2026-04-16 19:11:03--  https://raw.githubusercontent.com/brcktn/Inverse-Heat-PINN/main/training_data/constant_flux_DG.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1074172 (1.0M) [text/plain]
# Saving to: ‘constant_flux_DG.csv’
#
# constant_flux_DG.cs 100%[===================>]   1.02M  --.-KB/s    in 0.03s
#
# 2026-04-16 19:11:03 (34.9 MB/s) - ‘constant_flux_DG.csv’ saved [1074172/1074172]

# %%
class HeatPINN(nn.Module):
    """
    A simple feedforward neural network
    """
    def __init__(self, layers):
        """
        Parameters
        ----------
        layers : list
            A list of integers specifying the number of neurons in each layer, including input and output layers.
        """
        super(HeatPINN, self).__init__()

        self.layers = nn.ModuleList()
        for i in range(len(layers) - 1):
            self.layers.append(nn.Linear(layers[i], layers[i+1]))
            if i < len(layers) - 2:
                # self.layers.append(nn.Tanh())
                self.layers.append(nn.SiLU())

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
def sample_points(num_points, size, t_max):
    """
    Sample points uniformly from the domain [-L/2, L/2] x [-L/2, L/2] x [0, t_max]

    Parameters
    ----------
    num_points : int
        The number of points to sample.
    size : float
        The size of the spatial domain (length of the plate).
    t_max : float
        The maximum time to sample from.

    Returns
    -------
    torch.Tensor
        A tensor of shape (num_points, 3) containing the sampled points.
    """
    x = torch.rand(num_points, 1) * size - size / 2  # Sample x in [-L/2, L/2]
    y = torch.rand(num_points, 1) * size - size / 2  # Sample y in [-L/2, L/2]
    t = torch.rand(num_points, 1) * t_max  # Sample t in [0, t_max]

    x.requires_grad = True
    y.requires_grad = True
    t.requires_grad = True

    return torch.cat([x, y, t], dim=1)


def sample_boundary_points(num_points, size, t_max):
    """
    Uniformly samples points from the boundary of the plate
    over the full time interval.

    Parameters
    ----------
    num_points : int
        The number of points to sample.
    size : float
        The size of the spatial domain (length of the plate).
    t_max : float
        The maximum time to sample from.

    Returns
    -------
    tuple of torch.Tensor
        A tuple containing tensors for the left, right, top, and bottom edges of the plate
            (left_edge, right_edge, top_edge, bottom_edge), each of shape (num_points//4, 3).
    """
    points_per_edge = num_points // 4
    # left edge (x = -L/2)
    x_left = torch.full((points_per_edge, 1), -size / 2)
    y_left = torch.rand(points_per_edge, 1) * size - size / 2
    t_left = torch.rand(points_per_edge, 1) * t_max
    left_edge = torch.cat([x_left, y_left, t_left], dim=1)
    left_edge.requires_grad = True
    
    # right edge (x = L/2)
    x_right = torch.full((points_per_edge, 1), size / 2)
    y_right = torch.rand(points_per_edge, 1) * size - size / 2
    t_right = torch.rand(points_per_edge, 1) * t_max
    right_edge = torch.cat([x_right, y_right, t_right], dim=1)
    right_edge.requires_grad = True

    # top edge (y = -L/2)
    x_top = torch.rand(points_per_edge, 1) * size - size / 2
    y_top = torch.full((points_per_edge, 1), -size / 2)
    t_top = torch.rand(points_per_edge, 1) * t_max
    top_edge = torch.cat([x_top, y_top, t_top], dim=1)
    top_edge.requires_grad = True
    
    # bottom edge (y = L/2)
    x_bottom = torch.rand(points_per_edge, 1) * size - size / 2
    y_bottom = torch.full((points_per_edge, 1), size / 2)
    t_bottom = torch.rand(points_per_edge, 1) * t_max
    bottom_edge = torch.cat([x_bottom, y_bottom, t_bottom], dim=1)
    bottom_edge.requires_grad = True

    return left_edge, right_edge, top_edge, bottom_edge

# %%
def data_loss(model, x_batch, y_batch):
    """
    Supervised loss on sampled dataset points.

    Parameters
    ----------
    model : nn.Module
        The PINN model.
    x_batch : torch.Tensor
        A batch of input points (x, y, t).
    y_batch : torch.Tensor
        A batch of corresponding temperature values.
    
    Returns
    -------
    torch.Tensor
        The mean squared error loss between the model predictions and the true values.
    """
    x_batch = x_batch.to(device)
    y_batch = y_batch.to(device)
    pred = model(x_batch)
    return torch.mean((pred - y_batch) ** 2)


def physics_loss(model, points, alpha):
    """
    Physics loss enforcing the heat equation at sampled points.

    Parameters
    ----------
    model : nn.Module
        The PINN model.
    points : torch.Tensor
        A batch of input points (x, y, t) where the physics loss is evaluated.
    alpha : float
        The thermal diffusivity (known value).
    
    Returns
    -------
    torch.Tensor
        The mean squared error loss enforcing the heat equation at the given points.
    """
    points = points.to(device)
    pred = model(points)

    # Compute gradients for PDE residual
    grad = torch.autograd.grad(pred, points, grad_outputs=torch.ones_like(pred), create_graph=True)[0]
    u_t = grad[:, 2:3]  # Time derivative
    u_x = grad[:, 0:1]  # Spatial derivative in x
    u_y = grad[:, 1:2]  # Spatial derivative in y

    u_xx = torch.autograd.grad(u_x, points, grad_outputs=torch.ones_like(u_x), create_graph=True)[0][:, 0:1]
    u_yy = torch.autograd.grad(u_y, points, grad_outputs=torch.ones_like(u_y), create_graph=True)[0][:, 1:2]

    # Heat equation residual: u_t - alpha * (u_xx + u_yy) = 0
    residual = u_t - alpha * (u_xx + u_yy)
    
    return torch.mean(residual ** 2)


def boundary_loss(model, boundary_points):
    """
    Boundary loss enforcing the constant flux boundary conditions at sampled boundary points based on known q.

    Parameters
    ----------
    model : nn.Module
        The PINN model.
    boundary_points : tuple of torch.Tensor
        A tuple containing tensors for the left, right, top, and bottom edges of the plate
            (left_edge, right_edge, top_edge, bottom_edge), each of shape (num_points//4, 3).
    
    Returns
    -------
    torch.Tensor
        The mean squared error loss enforcing the boundary conditions at the given points.
    """
    left_edge, right_edge, top_edge, bottom_edge = boundary_points
    left_edge = left_edge.to(device)
    right_edge = right_edge.to(device)
    top_edge = top_edge.to(device)
    bottom_edge = bottom_edge.to(device)

    pred_left = model(left_edge)
    pred_right = model(right_edge)
    pred_top = model(top_edge)
    pred_bottom = model(bottom_edge)

    dT_dx_left = torch.autograd.grad(pred_left, left_edge, grad_outputs=torch.ones_like(pred_left), create_graph=True)[0][:, 0:1]
    dT_dx_right = torch.autograd.grad(pred_right, right_edge, grad_outputs=torch.ones_like(pred_right), create_graph=True)[0][:, 0:1]
    dT_dy_top = torch.autograd.grad(pred_top, top_edge, grad_outputs=torch.ones_like(pred_top), create_graph=True)[0][:, 1:2]
    dT_dy_bottom = torch.autograd.grad(pred_bottom, bottom_edge, grad_outputs=torch.ones_like(pred_bottom), create_graph=True)[0][:, 1:2]

    residual_left = dT_dx_left - q / alpha
    residual_right = dT_dx_right + q / alpha
    residual_top = dT_dy_top - q / alpha
    residual_bottom = dT_dy_bottom + q / alpha

    all_residuals = torch.cat([residual_left, residual_right, residual_top, residual_bottom], dim=0)
    return torch.mean(all_residuals ** 2)

# %%
def train(model, dataloader, optimizer):
    import time
    model.train()
    for epoch in range(epochs):
        epoch_start = time.time()
        total_loss = 0.0
        total_data_loss = 0.0
        total_physics_loss = 0.0
        total_boundary_loss = 0.0

        for x_batch, y_batch in dataloader:
            optimizer.zero_grad()

            # Sample points for physics and boundary losses
            physics_points = sample_points(batch_size, size, t_max)
            boundary_points = sample_boundary_points(batch_size, size, t_max)

            # Compute losses
            loss_data = data_loss(model, x_batch, y_batch)
            loss_physics = physics_loss(model, physics_points, alpha)
            loss_boundary = boundary_loss(model, boundary_points)
            
            # Total loss
            loss = loss_data + loss_physics + loss_boundary

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            total_loss += loss_data.item() + loss_physics.item() + loss_boundary.item() # unweighted for logging
            total_data_loss += loss_data.item()
            total_physics_loss += loss_physics.item()
            total_boundary_loss += loss_boundary.item()

        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(dataloader)
        avg_data_loss = total_data_loss / len(dataloader)
        avg_physics_loss = total_physics_loss / len(dataloader)
        avg_boundary_loss = total_boundary_loss / len(dataloader)

        print(f'Epoch {epoch+1:03d}/{epochs}, Loss (unweighted): {avg_loss:.6f}, Data: {avg_data_loss:.6f}, Physics: {avg_physics_loss:.6f}, Boundary: {avg_boundary_loss:.6f}, Time: {epoch_time:.2f}s')

# %%
model = HeatPINN(layers).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

train(model, dataloader, optimizer)
# Out:
# Epoch 001/20, Loss (unweighted): 2.314180, Data: 0.575332, Physics: 0.038152, Boundary: 1.700695, Time: 16.21s
# Epoch 002/20, Loss (unweighted): 0.086541, Data: 0.045312, Physics: 0.010588, Boundary: 0.030641, Time: 15.46s
# Epoch 003/20, Loss (unweighted): 0.028090, Data: 0.006890, Physics: 0.007936, Boundary: 0.013264, Time: 15.54s
# Epoch 004/20, Loss (unweighted): 0.020566, Data: 0.004106, Physics: 0.007327, Boundary: 0.009133, Time: 15.50s
# Epoch 005/20, Loss (unweighted): 0.018303, Data: 0.003360, Physics: 0.006942, Boundary: 0.008001, Time: 15.78s
# Epoch 006/20, Loss (unweighted): 0.014738, Data: 0.002951, Physics: 0.006669, Boundary: 0.005118, Time: 15.44s
# Epoch 007/20, Loss (unweighted): 0.015712, Data: 0.002781, Physics: 0.006445, Boundary: 0.006486, Time: 15.46s
# Epoch 008/20, Loss (unweighted): 0.013116, Data: 0.002723, Physics: 0.006471, Boundary: 0.003921, Time: 15.87s
# Epoch 009/20, Loss (unweighted): 0.012489, Data: 0.002564, Physics: 0.006344, Boundary: 0.003581, Time: 15.54s
# Epoch 010/20, Loss (unweighted): 0.012134, Data: 0.002489, Physics: 0.006182, Boundary: 0.003463, Time: 15.41s
# Epoch 011/20, Loss (unweighted): 0.011312, Data: 0.002400, Physics: 0.006156, Boundary: 0.002756, Time: 15.79s
# Epoch 012/20, Loss (unweighted): 0.011280, Data: 0.002363, Physics: 0.006087, Boundary: 0.002830, Time: 15.85s
# Epoch 013/20, Loss (unweighted): 0.010366, Data: 0.002266, Physics: 0.006011, Boundary: 0.002090, Time: 15.43s
# Epoch 014/20, Loss (unweighted): 0.010834, Data: 0.002197, Physics: 0.006003, Boundary: 0.002634, Time: 15.55s
# Epoch 015/20, Loss (unweighted): 0.010220, Data: 0.002120, Physics: 0.005859, Boundary: 0.002241, Time: 15.84s
# Epoch 016/20, Loss (unweighted): 0.010517, Data: 0.002139, Physics: 0.005863, Boundary: 0.002515, Time: 15.50s
# Epoch 017/20, Loss (unweighted): 0.009785, Data: 0.002080, Physics: 0.005701, Boundary: 0.002003, Time: 15.58s
# Epoch 018/20, Loss (unweighted): 0.009453, Data: 0.002071, Physics: 0.005718, Boundary: 0.001665, Time: 16.43s
# Epoch 019/20, Loss (unweighted): 0.009073, Data: 0.001945, Physics: 0.005658, Boundary: 0.001469, Time: 15.91s
# Epoch 020/20, Loss (unweighted): 0.009081, Data: 0.001940, Physics: 0.005585, Boundary: 0.001555, Time: 15.67s

# %%
def plot_heatmap(model, t, size=2.0, resolution=100):
    """
    Plot a heatmap of the temperature distribution at a given time.
    
    Parameters
    ----------
    model : nn.Module
        The trained PINN model.
    t : float
        The time at which to plot the temperature distribution.
    size : float
        The size of the spatial domain (length of the plate).
    resolution : int
        The number of points in each spatial dimension for the grid.
    """
    model.eval()
    
    # Create a grid of (x, y) points
    x = torch.linspace(-size/2, size/2, resolution)
    y = torch.linspace(-size/2, size/2, resolution)
    X, Y = torch.meshgrid(x, y, indexing='ij')
    
    # Flatten and create input tensor with constant time
    x_flat = X.flatten().unsqueeze(1)
    y_flat = Y.flatten().unsqueeze(1)
    t_tensor = torch.full_like(x_flat, t)
    
    points = torch.cat([x_flat, y_flat, t_tensor], dim=1).to(device)
    
    # Get predictions
    with torch.no_grad():
        u = model(points)
    
    # Reshape to grid
    U = u.reshape(resolution, resolution).cpu().numpy()
    
    # Plot
    plt.figure(figsize=(8, 6), dpi=100)
    plt.contourf(X.numpy(), Y.numpy(), U, levels=30, cmap='hot', vmin=0, vmax=1)
    plt.colorbar(label='Temperature')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'Temperature Distribution at t = {t:.2f}')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
    
    model.train()

plot_heatmap(model, t=0, size=size, resolution=100)

# %%
# drive.mount('/content/drive')
# timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
# torch.save(model.state_dict(), f'/content/drive/My Drive/Heat PINN weights/heat_pinn_model_{timestamp}.pth')
